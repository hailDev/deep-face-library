# %%
# !pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.91-py3-none-any.whl (97 kB)
# Collecting retina-face>=0.0.1
#   Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (0.1.1)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (4.7.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (2.13.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (2.1.3)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (10.1.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (2.13.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (1.24.3)
# Collecting fire>=0.4.0
#   Downloading fire-0.6.0.tar.gz (88 kB)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (3.0.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (4.8.1.78)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from deepface) (4.66.1)
# Requirement already satisfied: packaging in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.2)
# Requirement already satisfied: filelock in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: six in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from gdown>=3.10.1->deepface) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->deepface) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->deepface) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->deepface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: tensorflow-intel==2.13.0; platform_system == "Windows" in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: termcolor in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from fire>=0.4.0->deepface) (2.3.0)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from Flask>=1.1.2->deepface) (6.8.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.1)
# Requirement already satisfied: click>=8.1.3 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from Flask>=1.1.2->deepface) (1.7.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (4.25.1)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (3.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (4.5.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1; platform_machine != "arm64" or platform_system != "Darwin" in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: setuptools in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (49.2.1)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (1.59.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.1.2->deepface) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from Werkzeug>=3.0.0->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (0.41.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (3.5.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (5.3.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\crozi\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow>=1.9.0->deepface) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117049 sha256=6618349b012d9e00248e89b77729a297da037d8120e9f3160d9028dab80476ac
#   Stored in directory: c:\users\crozi\appdata\local\pip\cache\wheels\ec\ce\ba\9d5764d2266c500c18776c7d8f1e3c023075994cbc6dea47db
# Successfully built fire
# Installing collected packages: retina-face, gunicorn, fire, deepface
# Successfully installed deepface-0.0.91 fire-0.6.0 gunicorn-22.0.0 retina-face-0.0.17
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\crozi\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
import os
folder1 = "anggota kelas"
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            channels = img.shape[-1] if img.ndim == 3 else 1
            if channels==1 :
              rgb_image = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) * 255
              images.append(rgb_image)
            else:
              images.append(img)
    return images
x=load_images_from_folder(folder1)

# %%
plt.figure(figsize=(10,10))
for i in range(35):
    plt.subplot(11,11,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[i])
plt.show()

# %%
#importing the images
img1_path = 'anggota kelas/darwiN(4).jpg'
img2_path = 'anggota kelas/darwiN(2).jpg'
#img3_path = '/content/Img3.jpg'
#confirming the path of images
img1 = cv2.imread(img1_path)
img2 = cv2.imread(img2_path)

# %%
plt.imshow(img1[:, :, ::-1 ]) #setting value as -1 to maintain saturation
plt.show()
plt.imshow(img2[:, :, ::-1 ])
plt.show()

# %%
#calling VGGFace
model_name = "VGG-Face"
model = DeepFace.build_model(model_name)

# %%
#calling Facenet
model_name = "Facenet"
model = DeepFace.build_model(model_name)

# %%
result = DeepFace.verify(img1_path,img2_path)#validate our images
DeepFace.verify(img1,img2)#generating result of comparison
# Out:
# {'verified': True,
#  'distance': 0.5980368401450353,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 657,
#    'y': 598,
#    'w': 194,
#    'h': 194,
#    'left_eye': (781, 672),
#    'right_eye': (719, 673)},
#   'img2': {'x': 331,
#    'y': 295,
#    'w': 110,
#    'h': 110,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 3.02}

# %%
img4_path = 'non-anggota kelas/Presiden Susilo Bambang Yudhoyono.png' #setting path for different image
img4 = cv2.imread(img4_path)
#plotting the image
plt.imshow(img4[:, :, ::-1 ])
plt.show()

# %%
#comparing the faces in images using VGG Face
DeepFace.verify("anggota kelas/darwiN(2).jpg","non-anggota kelas/Presiden Susilo Bambang Yudhoyono.png")
# Out:
# {'verified': False,
#  'distance': 0.7370567499119105,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 331,
#    'y': 295,
#    'w': 110,
#    'h': 110,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 154,
#    'y': 91,
#    'w': 188,
#    'h': 188,
#    'left_eye': (276, 167),
#    'right_eye': (212, 163)}},
#  'time': 1.25}
